# %% [markdown]
# ### **Web Scraping LinkedIn Articles Data**
# ##### *Description:* Developed a Python script for web scraping LinkedIn articles data. Utilized the requests library for fetching HTML content, and BeautifulSoup for parsing and extracting relevant information. Extracted questions, contribution counts, timestamps, article descriptions, and tagged topics. Organized the data into a Pandas DataFrame and saved it as a CSV file.
# ##### *Technologies:* Python, requests, BeautifulSoup, Pandas.
# ##### *Skills:* Web scraping, data extraction, Python scripting, data manipulation.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ###### URL of the LinkedIn Articles page

# %%
url='https://www.linkedin.com/pulse/topics/home/?trk=guest_homepage-basic_guest_nav_menu_articles'

# %% [markdown]
# ###### with the help of requests if we get the response of 200 it means that we can scrap that page

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
data=page.text

# %%
soup=bs(data,"html.parser")

# %% [markdown]
# ###### Printing out the prettified HTML content and title

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_career_advice_hub_home" name="pageKey"/>
#   <!-- -->
#   <!-- -->
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="0.0.3176" data-browser-id="15b6d0b3-45c9-44b1-8a88-0675c18fdb0f" data-call-tree-id="AAYQLQ5duGN9VfPcF+/41Q==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="article-ssr-frontend" data-page-instance="urn:li:page:d_career_advice_hub_home;h94hQ7ZwRGCJcZiJsrQr/A==" data-service-name="article-ssr-frontend" id="config"/>
#   <link href="https://www.linkedin.com/pulse/topics/home/" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#   <script>
#    function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
#           window.lazyloader = getDfd();
#           window.tracking = getDfd();
#           window.impressionTracking = getDfd();
#           window.ingraphTracking = getDfd();
#           window.appDetection = getDfd();
#           window.pemTracking = getDfd();
#   </script>
#   <!-- -->
#   <title>
#    Discover thousands of collaborative articles on 2500+ skills
#   </title>
#   <meta content="Discover 100 collaborative articles on domains such as Marketing, Public Administration, and Healthcare. Our expertly curated collection combines AI-generated content with insights and advice from industry experts, providing you with unique perspectives and up-to-date information on many skills and their applications." name="description"/>
#   <meta content="Discover thousands of collaborative articles on 2500+ skills" property="og:title"/>
#   <meta content="Discover 100 collaborative articles on domains such as Marketing, Public Administration, and Healthcare. Our expertly curated collection combines AI-generated content with insights and advice from industry experts, providing you with unique perspectives and up-to-date information on many skills and their applications." property="og:description"/>
#   <meta content="https://static.licdn.com/aero-v1/sc/h/6dwv6w0gvj6q3ye8o19b99or2" property="og:image"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://www.linkedin.com/pulse/topics/home/" property="og:url"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@LinkedInEditors" name="twitter:site"/>
#   <meta content="Discover thousands of collaborative articles on 2500+ skills" name="twitter:title"/>
#   <meta content="Discover 100 collaborative articles on domains such as Marketing, Public Administration, and Healthcare. Our expertly curated collection combines AI-generated content with insights and advice from industry experts, providing you with unique perspectives and up-to-date information on many skills and their applications." name="twitter:description"/>
#   <meta content="https://static.licdn.com/aero-v1/sc/h/6dwv6w0gvj6q3ye8o19b99or2" name="twitter:image"/>
#   <meta content="noarchive, max-image-preview:large" name="robots"/>
#   <meta name="appId"/>
#   <!-- -->
#   <!-- -->
#   <meta content="1" data-counter-metric-endpoint="/pulse/api/ingraphs/counter" data-gauge-metric-endpoint="/pulse/api/ingraphs/gauge" name="clientSideIngraphs"/>
#   <link href="https://static.licdn.com/aero-v1/sc/h/6s0ekwefwdvtxr5oiollo67a" rel="stylesheet"/>
#   <!-- -->
#  </head>
#  <body dir="ltr">
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <div class="contextual-sign-in-modal" data-cool-off-enabled="" data-impression-id="content-hub-home-page_contextual-sign-in-modal">
#    <!-- -->
#    <div class="">
#     <!-- -->
#     <div class="modal modal--contextual-sign-in" data-outlet="content-hub-home-page_contextual-sign-in" id="content-hub-home-page_contextual-sign-in">
#      <!-- -->
#      <div class="modal__overlay flex items-center bg-color-background-scrim justify-center fixed bottom-0 left-0 right-0 top-0 opacity-0 invisible pointer-events-none z-[1000] transition-[opacity] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.17s] py-4">
#       <section aria-labelledby="content-hub-home-page_contextual-sign-in-modal-header" aria-modal="true" class="max-h-full modal__wrapper overflow-auto p-0 bg-color-surface max-w-[1128px] min-h-[160px] relative scale-[0.25] shadow-sm shadow-color-border-faint transition-[transform] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.33s] focus:outline-0 w-[1128px] mamabear:w-[744px] babybear:w-[360px] rounded-md" role="dialog" tabindex="-1">
#        <button aria-label="Dismiss" class="modal__dismiss btn-tertiary h-[40px] w-[40px] p-0 rounded-full indent-0 contextual-sign-in-modal__modal-dismiss absolute right-0 m-[20px] cursor-pointer" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_modal_dismiss">
#         <icon class="contextual-sign-in-modal__modal-dismiss-icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/gs508lg3t2o81tq7pmcgn6m2">
#         </icon>
#        </button>
#        <div class="modal__main w-full">
#         <div class="contextual-sign-in-modal__screen contextual-sign-in-modal__context-screen flex flex-col my-4 mx-3">
#          <img alt="" class="inline-block relative w-16 h-16 contextual-sign-in-modal__img m-auto" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/5k9cgtx8rhoyqkcxfoncu1svl" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9l8dv1r8a09nem281grvopn9l"/>
#          <h2 class="contextual-sign-in-modal__context-screen-title font-sans text-xl text-color-text my-2 mx-4 text-center" id="content-hub-home-page_contextual-sign-in-modal-header">
#           Sign in to view more content
#          </h2>
#          <p class="contextual-sign-in-modal__subtitle mb-2 mx-12 babybear:mx-0 text-center font-sans text-md text-color-text">
#           Create your free account or sign in to continue your search
#          </p>
#          <!-- -->
#          <div class="contextual-sign-in-modal__btn-container m-auto w-[320px] babybear:w-full">
#           <!-- -->
#           <div class="sign-in-modal" data-impression-id="content-hub-home-page_contextual-sign-in-modal_sign-in-modal">
#            <button class="sign-in-modal__outlet-btn cursor-pointer btn-md btn-primary" data-modal="content-hub-home-page_contextual-sign-in_sign-in-modal" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_outlet-button">
#             Sign in
#            </button>
#            <div class="">
#             <!-- -->
#             <div class="modal modal--sign-in" data-outlet="content-hub-home-page_contextual-sign-in_sign-in-modal" id="content-hub-home-page_contextual-sign-in_sign-in-modal">
#              <!-- -->
#              <div class="modal__overlay flex items-center bg-color-background-scrim justify-center fixed bottom-0 left-0 right-0 top-0 opacity-0 invisible pointer-events-none z-[1000] transition-[opacity] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.17s] py-4">
#               <section aria-labelledby="content-hub-home-page_contextual-sign-in_sign-in-modal-modal-header" aria-modal="true" class="max-h-full modal__wrapper overflow-auto p-0 bg-color-surface max-w-[1128px] min-h-[160px] relative scale-[0.25] shadow-sm shadow-color-border-faint transition-[transform] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.33s] focus:outline-0 w-[1128px] mamabear:w-[744px] babybear:w-[360px] rounded-md" role="dialog" tabindex="-1">
#                <button aria-label="Dismiss" class="modal__dismiss btn-tertiary h-[40px] w-[40px] p-0 rounded-full indent-0 sign-in-modal__dismiss absolute right-0 cursor-pointer m-[20px]" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_dismiss">
#                 <icon class="sign-in-modal__dismiss-icon" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/gs508lg3t2o81tq7pmcgn6m2">
#                 </icon>
#                </button>
#                <div class="modal__main w-full">
#                 <div class="sign-in-modal__screen flex flex-col py-4 px-3 w-[513px] babybear:w-full">
#                  <h2 class="sign-in-modal__header font-sans text-display-md text-color-text">
#                   Welcome back
#                  </h2>
#                  <code id="i18n_sign_in_form_show_text" style="display: none">
#                   <!--"Show"-->
#                  </code>
#                  <code id="i18n_sign_in_form_show_label" style="display: none">
#                   <!--"Show your LinkedIn password"-->
#                  </code>
#                  <code id="i18n_sign_in_form_hide_text" style="display: none">
#                   <!--"Hide"-->
#                  </code>
#                  <code id="i18n_sign_in_form_hide_label" style="display: none">
#                   <!--"Hide your LinkedIn password"-->
#                  </code>
#                  <code id="i18n_username_error_empty" style="display: none">
#                   <!--"Please enter an email address or phone number"-->
#                  </code>
#                  <code id="i18n_username_error_too_long" style="display: none">
#                   <!--"Email or phone number must be between 3 to 128 characters"-->
#                  </code>
#                  <code id="i18n_username_error_too_short" style="display: none">
#                   <!--"Email or phone number must be between 3 to 128 characters"-->
#                  </code>
#                  <code id="i18n_password_error_empty" style="display: none">
#                   <!--"Please enter a password"-->
#                  </code>
#                  <code id="i18n_password_error_too_short" style="display: none">
#                   <!--"The password you provided must have at least 6 characters"-->
#                  </code>
#                  <code id="i18n_password_error_too_long" style="display: none">
#                   <!--"The password you provided must have at most 400 characters"-->
#                  </code>
#                  <form action="https://www.linkedin.com/uas/login-submit" class="mt-1.5 mb-2" data-id="sign-in-form" method="post" novalidate="">
#                   <input name="loginCsrfParam" type="hidden" value="15b6d0b3-45c9-44b1-8a88-0675c18fdb0f"/>
#                   <div class="flex flex-col">
#                    <div class="mt-1.5" data-js-module-id="guest-input">
#                     <div class="flex flex-col">
#                      <label class="input-label mb-1" for="content-hub-home-page_contextual-sign-in_sign-in-modal_session_key">
#                       Email or phone
#                      </label>
#                      <div class="text-input flex">
#                       <input autocomplete="username" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="content-hub-home-page_contextual-sign-in_sign-in-modal_session_key" name="session_key" required="" type="text"/>
#                      </div>
#                     </div>
#                     <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="content-hub-home-page_contextual-sign-in_sign-in-modal_session_key" role="alert">
#                     </p>
#                    </div>
#                    <div class="mt-1.5" data-js-module-id="guest-input">
#                     <div class="flex flex-col">
#                      <label class="input-label mb-1" for="content-hub-home-page_contextual-sign-in_sign-in-modal_session_password">
#                       Password
#                      </label>
#                      <div class="text-input flex">
#                       <input autocomplete="current-password" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="content-hub-home-page_contextual-sign-in_sign-in-modal_session_password" name="session_password" required="" type="password"/>
#                       <button aria-label="Show your LinkedIn password" aria-live="assertive" class="font-sans text-md font-bold text-color-action z-10 ml-[12px] hover:cursor-pointer" data-id="sign-in-form__password-visibility-toggle" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_sign-in-password-visibility-toggle-btn" type="button">
#                        Show
#                       </button>
#                      </div>
#                     </div>
#                     <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="content-hub-home-page_contextual-sign-in_sign-in-modal_session_password" role="alert">
#                     </p>
#                    </div>
#                    <input name="session_redirect" type="hidden" value="https://www.linkedin.com/pulse/topics/home/"/>
#                    <!-- -->
#                   </div>
#                   <div class="flex justify-between sign-in-form__footer--full-width" data-id="sign-in-form__footer">
#                    <a class="font-sans text-md font-bold link leading-regular sign-in-form__forgot-password--full-width" data-id="sign-in-form__forgot-password" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=content-hub-home-page_contextual-sign-in-modal_sign-in-modal_forgot_password">
#                     Forgot password?
#                    </a>
#                    <!-- -->
#                    <input name="trk" type="hidden" value="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_sign-in-submit"/>
#                    <button class="btn-md btn-primary flex-shrink-0 cursor-pointer sign-in-form__submit-btn--full-width" data-id="sign-in-form__submit-btn" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_sign-in-submit-btn" data-tracking-litms="" type="submit">
#                     Sign in
#                    </button>
#                   </div>
#                   <div class="sign-in-form__divider left-right-divider pt-2 pb-3">
#                    <p class="sign-in-form__divider-text font-sans text-sm text-color-text px-2">
#                     or
#                    </p>
#                   </div>
#                  </form>
#                  <div class="w-full max-w-[400px] mx-auto">
#                   <div class="google-auth-button">
#                    <code id="isTermsAndConditionsSkipEnabledAuthButton" style="display: none">
#                     <!--true-->
#                    </code>
#                    <p class="linkedin-tc__text text-color-text-low-emphasis text-xs pb-2" data-impression-id="content-hub-home-page_contextual-sign-in-modal_sign-in-modal__button-skip-tc-text">
#                     By clicking Continue, you agree to LinkedIn’s
#                     <a data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_user-agreement" data-tracking-will-navigate="true" href="/legal/user-agreement?trk=content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_user-agreement" target="_blank">
#                      User Agreement
#                     </a>
#                     ,
#                     <a data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_privacy-policy" data-tracking-will-navigate="true" href="/legal/privacy-policy?trk=content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_privacy-policy" target="_blank">
#                      Privacy Policy
#                     </a>
#                     , and
#                     <a data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_cookie-policy" data-tracking-will-navigate="true" href="/legal/cookie-policy?trk=content-hub-home-page_contextual-sign-in-modal_sign-in-modal_auth-button_cookie-policy" target="_blank">
#                      Cookie Policy
#                     </a>
#                     .
#                    </p>
#                    <div class="google-auth-button__placeholder">
#                    </div>
#                   </div>
#                  </div>
#                  <!-- -->
#                  <p class="sign-in-modal__join-now m-auto font-sans text-md text-color-text mt-2">
#                   New to LinkedIn?
#                   <a class="sign-in-modal__join-link" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_sign-in-modal_join-link" data-tracking-will-navigate="true" href="https://www.linkedin.com/signup/cold-join?session_redirect=%2Fpulse%2Ftopics%2Fhome%2F%3Ftrk%3Dguest_homepage-basic_guest_nav_menu_articles&amp;trk=content-hub-home-page_contextual-sign-in-modal_sign-in-modal_join-link">
#                    Join now
#                   </a>
#                  </p>
#                 </div>
#                </div>
#                <!-- -->
#               </section>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="contextual-sign-in-modal__divider left-right-divider">
#            <p class="contextual-sign-in-modal__divider-text font-sans text-sm text-color-text px-2">
#             or
#            </p>
#           </div>
#           <div class="w-full max-w-[400px] mx-auto">
#            <div class="google-auth-button">
#             <code id="isTermsAndConditionsSkipEnabledAuthButton" style="display: none">
#              <!--true-->
#             </code>
#             <p class="linkedin-tc__text text-color-text-low-emphasis text-xs pb-2" data-impression-id="content-hub-home-page__button-skip-tc-text">
#              By clicking Continue, you agree to LinkedIn’s
#              <a data-tracking-control-name="content-hub-home-page_auth-button_user-agreement" data-tracking-will-navigate="true" href="/legal/user-agreement?trk=content-hub-home-page_auth-button_user-agreement" target="_blank">
#               User Agreement
#              </a>
#              ,
#              <a data-tracking-control-name="content-hub-home-page_auth-button_privacy-policy" data-tracking-will-navigate="true" href="/legal/privacy-policy?trk=content-hub-home-page_auth-button_privacy-policy" target="_blank">
#               Privacy Policy
#              </a>
#              , and
#              <a data-tracking-control-name="content-hub-home-page_auth-button_cookie-policy" data-tracking-will-navigate="true" href="/legal/cookie-policy?trk=content-hub-home-page_auth-button_cookie-policy" target="_blank">
#               Cookie Policy
#              </a>
#              .
#             </p>
#             <div class="google-auth-button__placeholder">
#             </div>
#            </div>
#           </div>
#          </div>
#          <p class="contextual-sign-in-modal__join-now m-auto font-sans text-md text-color-text">
#           New to LinkedIn?
#           <a class="contextual-sign-in-modal__join-link" data-tracking-control-name="content-hub-home-page_contextual-sign-in-modal_join-link" data-tracking-will-navigate="true" href="https://www.linkedin.com/signup/cold-join?session_redirect=%2Fpulse%2Ftopics%2Fhome%2F%3Ftrk%3Dguest_homepage-basic_guest_nav_menu_articles&amp;trk=content-hub-home-page_contextual-sign-in-modal_join-link">
#            Join now
#           </a>
#          </p>
#         </div>
#        </div>
#        <!-- -->
#       </section>
#      </div>
#     </div>
#    </div>
#   </div>
#   <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#    Skip to main content
#   </a>
#   <header class="header base-detail-page__header px-mobile-container-padding bg-color-background-container global-alert-offset">
#    <nav aria-label="Primary" class="nav pt-1.5 pb-2 flex items-center justify-between relative flex-nowrap mamabear:flex-wrap mamabear:gap-y-1 babybear:flex-wrap babybear:py-1.5">
#     <a class="nav__logo-link link-no-visited-state z-1 mr-auto babybear:z-0 babybear:mr-0 babybear:flex-1 hover:no-underline focus:no-underline active:no-underline" data-tracking-control-name="content-hub-home-page_nav-header-logo" data-tracking-will-navigate="" href="/?trk=content-hub-home-page_nav-header-logo">
#      <span class="sr-only">
#       LinkedIn
#      </span>
#      <!-- -->
#      <icon class="block text-color-brand w-[84px] h-[21px] papabear:w-[135px] papabear:h-[34px]" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/8fkga714vy9b2wk5auqo5reeb" data-test-id="nav-logo">
#      </icon>
#     </a>
#     <!-- -->
#     <ul class="top-nav-menu flex items-center mr-0.5 babybear:hidden mamabear:hidden after:up-down-divider after:!h-[37px] nav__menu order-3">
#      <li class="">
#       <a class="top-nav-link flex justify-center items-center h-[52px] hover:text-color-text visited:hover:text-color-text hover:no-underline w-[64px] flex-col mx-1 text-color-text-secondary visited:text-color-text-secondary" data-tracking-control-name="content-hub-home-page_guest_nav_menu_articles" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/home/?trk=content-hub-home-page_guest_nav_menu_articles">
#        <icon class="top-nav-link__icon flex h-3 w-3 flex-shrink-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/6ulnj3n2ijcmhej768y6oj1hr">
#        </icon>
#        <span class="top-nav-link__label-text font-sans text-xs leading-regular text-center font-regular">
#         Articles
#        </span>
#       </a>
#      </li>
#      <li class="">
#       <a class="top-nav-link flex justify-center items-center h-[52px] hover:text-color-text visited:hover:text-color-text hover:no-underline w-[64px] flex-col mx-1 text-color-text-secondary visited:text-color-text-secondary" data-tracking-control-name="content-hub-home-page_guest_nav_menu_people" data-tracking-will-navigate="" href="https://www.linkedin.com/pub/dir/+/+?trk=content-hub-home-page_guest_nav_menu_people">
#        <icon class="top-nav-link__icon flex h-3 w-3 flex-shrink-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/7kb6sn3tm4cx918cx9a5jlb0">
#        </icon>
#        <span class="top-nav-link__label-text font-sans text-xs leading-regular text-center font-regular">
#         People
#        </span>
#       </a>
#      </li>
#      <li class="">
#       <a class="top-nav-link flex justify-center items-center h-[52px] hover:text-color-text visited:hover:text-color-text hover:no-underline w-[64px] flex-col mx-1 text-color-text-secondary visited:text-color-text-secondary" data-tracking-control-name="content-hub-home-page_guest_nav_menu_learning" data-tracking-will-navigate="" href="https://www.linkedin.com/learning/search?trk=content-hub-home-page_guest_nav_menu_learning">
#        <icon class="top-nav-link__icon flex h-3 w-3 flex-shrink-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/8wykgzgbqy0t3fnkgborvz54u">
#        </icon>
#        <span class="top-nav-link__label-text font-sans text-xs leading-regular text-center font-regular">
#         Learning
#        </span>
#       </a>
#      </li>
#      <li class="">
#       <a class="top-nav-link flex justify-center items-center h-[52px] hover:text-color-text visited:hover:text-color-text hover:no-underline w-[64px] flex-col mx-1 text-color-text-secondary visited:text-color-text-secondary" data-tracking-control-name="content-hub-home-page_guest_nav_menu_jobs" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/search?trk=content-hub-home-page_guest_nav_menu_jobs">
#        <icon class="top-nav-link__icon flex h-3 w-3 flex-shrink-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/92eb1xekc34eklevj0io6x4ki">
#        </icon>
#        <span class="top-nav-link__label-text font-sans text-xs leading-regular text-center font-regular">
#         Jobs
#        </span>
#       </a>
#      </li>
#     </ul>
#     <div class="nav__cta-container order-3 flex gap-x-1 justify-end min-w-[100px] flex-nowrap flex-shrink-0 babybear:flex-wrap flex-2">
#      <a class="nav__button-tertiary btn-md btn-tertiary" data-test-live-nav-primary-cta="" data-tracking-control-name="content-hub-home-page_nav-header-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?session_redirect=%2Fpulse%2Ftopics%2Fhome%2F%3Ftrk%3Dguest_homepage-basic_guest_nav_menu_articles&amp;trk=content-hub-home-page_nav-header-join">
#       Join now
#      </a>
#      <a class="nav__button-secondary btn-md btn-secondary-emphasis" data-tracking-control-name="content-hub-home-page_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/login?session_redirect=%2Fpulse%2Ftopics%2Fhome%2F%3Ftrk%3Dguest_homepage-basic_guest_nav_menu_articles&amp;fromSignIn=true&amp;trk=content-hub-home-page_nav-header-signin">
#       Sign in
#      </a>
#      <!-- -->
#     </div>
#     <!-- -->
#     <!-- -->
#    </nav>
#   </header>
#   <!-- -->
#   <!-- -->
#   <main class="main papabear:flex papabear:w-content-max-w papabear:mx-auto papabear:pt-desktop-content-top-margin mamabear:pt-desktop-content-top-margin" id="main-content" role="main">
#    <section class="core-rail mx-auto papabear:w-core-rail-width mamabear:max-w-[790px] babybear:max-w-[790px]">
#     <div class="details mx-details-container-padding">
#      <div class="content-hub-home-core-rail">
#       <section class="core-section-container my-3 content-hub-explore-articles">
#        <h2 class="text-display-md font-semibold text-color-text babybear:text-xl">
#         Learn more about Collaborative Articles
#        </h2>
#        <!-- -->
#        <!-- -->
#        <div class="core-section-container__content break-words">
#         <p class="text-light font-sans text-md no-underline babybear:text-sm">
#          We’re unlocking community knowledge in an all new way. It starts with an article on a professional topic or skill, written with the help of AI — but it’s not complete without insights and advice from people with real-life experiences. We invited experts to contribute.
#          <a aria-label="Learn more about Collaborative Articles" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="true" href="https://www.linkedin.com/help/linkedin/answer/a1413111" target="_blank">
#           Learn more
#          </a>
#         </p>
#        </div>
#       </section>
#       <!-- -->
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/your-team-struggling-keep-up-productivity-what-mentoring-gtekf" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="Your team is struggling to keep up with productivity. What mentoring software should you consider?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D4E12AQFymmVUg_T7Ag/article-cover_image-shrink_720_1280/0/1674482547347?e=2147483647&amp;v=beta&amp;t=w4jmmJR6fs85CVH6F8X_jZwtJZ3BVCLBkPW5ClK9FoI"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/your-team-struggling-keep-up-productivity-what-mentoring-gtekf" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            Your team is struggling to keep up with productivity. What mentoring software should you consider?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D5603AQGG8acAGWm4nw/profile-displayphoto-shrink_400_400/0/1694177212082?e=2147483647&amp;v=beta&amp;t=fUKOWEsWkYqulElPT5wb0ZsM1T2hy2Bij3Z1GnCm_p4" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D4E03AQH_yYFxZcMukQ/profile-displayphoto-shrink_400_400/0/1701293417821?e=2147483647&amp;v=beta&amp;t=Ww-4fl6D2wC5M7QysZ1oPT3tI1-vMfTXtoGVuqRF1KM" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
#            <span class="pr-0.5 pt-0.5">
#             45 contributions
#            </span>
#            <span class="before:middot pt-0.5">
#             6 minutes ago
#            </span>
#           </div>
#           <p class="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs">
#            Learn how to choose the best mentoring software for your team's productivity. Consider features, ease of use, support, cost, reviews, and trial.
#           </p>
#          </a>
#          <div class="content-hub-tagged-topics flex flex-row flex-wrap font-sans text-sm font-[500] babybear:w-fit babybear:text-xs">
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/mentoring-s1939/">
#            Mentoring
#           </a>
#           <span class="before:middot px-0.5 text-color-text before:no-underline">
#           </span>
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/">
#            Soft Skills
#           </a>
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/what-most-effective-tools-managing-your-technical-zbyhe" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="What are the most effective tools for managing your technical support team's schedules?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D5612AQEBu96ZF7ti6w/article-cover_image-shrink_720_1280/0/1674366135326?e=2147483647&amp;v=beta&amp;t=cYg2VtlAwVK_m3N0zU-qB3ZkVDGYa2DkAbOvH5amth4"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/what-most-effective-tools-managing-your-technical-zbyhe" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            What are the most effective tools for managing your technical support team's schedules?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D5603AQGG8acAGWm4nw/profile-displayphoto-shrink_400_400/0/1694177212082?e=2147483647&amp;v=beta&amp;t=fUKOWEsWkYqulElPT5wb0ZsM1T2hy2Bij3Z1GnCm_p4" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D5603AQH4ieYr3pK74Q/profile-displayphoto-shrink_400_400/0/1700062076798?e=2147483647&amp;v=beta&amp;t=OkPPRJsk_EgEY-CY8yWgcqa_EhciNLC7ndLuVHgx4zQ" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D5603AQFoAtsIqlnJXw/profile-displayphoto-shrink_400_400/0/1694340030364?e=2147483647&amp;v=beta&amp;t=f4ilzg5aL3rJLB59d3Od-JJ0krEfI_L8HWCnsjztPyg" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
#            <span class="pr-0.5 pt-0.5">
#             18 contributions
#            </span>
#            <span class="before:middot pt-0.5">
#             3 minutes ago
#            </span>
#           </div>
#           <p class="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs">
#            Learn about the best tools to automate, optimize, and streamline your technical support team's schedules, and improve your team's productivity, satisfaction, and…
#           </p>
#          </a>
#          <div class="content-hub-tagged-topics flex flex-row flex-wrap font-sans text-sm font-[500] babybear:w-fit babybear:text-xs">
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/it-services-s57547/technical-support-s68/">
#            Technical Support
#           </a>
#           <span class="before:middot px-0.5 text-color-text before:no-underline">
#           </span>
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/it-services-s57547/">
#            IT Services
#           </a>
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/1/youre-managing-virtual-team-how-can-you-ensure-project-8uqxe" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="You're managing a virtual team. How can you ensure project management success?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D4D12AQHmXYRyH3xZPA/article-cover_image-shrink_720_1280/0/1674481263537?e=2147483647&amp;v=beta&amp;t=i6n_CC_bw3Kqm8dqp7VMvR4ggExb7HJRxVF73yT-roI"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/1/youre-managing-virtual-team-how-can-you-ensure-project-8uqxe" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            You're managing a virtual team. How can you ensure project management success?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 bg-color-entity-ghost-background face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D4D03AQHImhJ_8V-GRQ/profile-displayphoto-shrink_400_400/0/1675792647988?e=2147483647&amp;v=beta&amp;t=Gawn87yTuRQnfslW7WIx3OqkS261RfUfNvMO0M503dw" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D4E03AQFJ8qfwdfw4Lw/profile-displayphoto-shrink_400_400/0/1676671046342?e=2147483647&amp;v=beta&amp;t=gesI5X6E3gJ30gl_cVcN0DdGRzLwVQZ7Md8UvCfXVWU" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
#            <span class="pr-0.5 pt-0.5">
#             38 contributions
#            </span>
#            <span class="before:middot pt-0.5">
#             1 minute ago
#            </span>
#           </div>
#           <p class="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs">
#            Learn how to use facilitation skills and tools to manage your virtual team and project effectively and successfully.
#           </p>
#          </a>
#          <div class="content-hub-tagged-topics flex flex-row flex-wrap font-sans text-sm font-[500] babybear:w-fit babybear:text-xs">
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/facilitation-s1166/">
#            Facilitation
#           </a>
#           <span class="before:middot px-0.5 text-color-text before:no-underline">
#           </span>
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/">
#            Soft Skills
#           </a>
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/1/your-hr-department-needs-mentoring-tools-how-do-you-choose-6qsac" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="Your HR department needs mentoring tools. How do you choose the best ones?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D4E12AQEMhBnRRDHElw/article-cover_image-shrink_720_1280/0/1674482572620?e=2147483647&amp;v=beta&amp;t=2mwX-RI52U1CFz6CAEgK0trGaBsOBSJsClpvzEBhlIM"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/1/your-hr-department-needs-mentoring-tools-how-do-you-choose-6qsac" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            Your HR department needs mentoring tools. How do you choose the best ones?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D5603AQFbcGS6RCMfUg/profile-displayphoto-shrink_400_400/0/1698601855405?e=2147483647&amp;v=beta&amp;t=f6abIFhH12hURlb9UB3GTdkY9RQX2sKt6REPVVouVLk" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/C4D03AQGcJq0YRh6ixA/profile-displayphoto-shrink_400_400/0/1629995599796?e=2147483647&amp;v=beta&amp;t=EBaZD2GRj32nXXzMWENUDJc6t6aS7nozbtdQhTa9wGk" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/C4D03AQFCu63pibbGiQ/profile-displayphoto-shrink_400_400/0/1664245122580?e=2147483647&amp;v=beta&amp;t=67FstkOrR12vs5xGd0tTbnMUI0RBR0r6A5xhitNTqyk" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
#            <span class="pr-0.5 pt-0.5">
#             21 contributions
#            </span>
#            <span class="before:middot pt-0.5">
#             23 minutes ago
#            </span>
#           </div>
#           <p class="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs">
#            Learn how to find the best mentoring tools for your HR department. Discover how to assess your needs, compare your options, and test your choices.
#           </p>
#          </a>
#          <div class="content-hub-tagged-topics flex flex-row flex-wrap font-sans text-sm font-[500] babybear:w-fit babybear:text-xs">
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/mentoring-s1939/">
#            Mentoring
#           </a>
#           <span class="before:middot px-0.5 text-color-text before:no-underline">
#           </span>
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/soft-skills-s2976/">
#            Soft Skills
#           </a>
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/0/what-does-electronic-specialist-do-skills-computer-engineering-nhwie" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="What does an electronic specialist do?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D4E12AQFgjOTxHRc9Eg/article-cover_image-shrink_720_1280/0/1674668560233?e=2147483647&amp;v=beta&amp;t=yo_X6qE-UU6GGuKfnb-qV2q771UuylXWH0ACkTjwacY"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/0/what-does-electronic-specialist-do-skills-computer-engineering-nhwie" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            What does an electronic specialist do?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/C5603AQH70khB54aTPg/profile-displayphoto-shrink_400_400/0/1516358873189?e=2147483647&amp;v=beta&amp;t=oyTzk4GmnktouXzXXScCYNyt5UGB4_z5Xqi63EkP8Tc" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
#            <span class="pr-0.5 pt-0.5">
#             5 contributions
#            </span>
#            <span class="before:middot pt-0.5">
#             9 hours ago
#            </span>
#           </div>
#           <p class="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs">
#            Learn what an electronic specialist does, what skills and qualifications you need, and what industries and sectors you can work in.
#           </p>
#          </a>
#          <div class="content-hub-tagged-topics flex flex-row flex-wrap font-sans text-sm font-[500] babybear:w-fit babybear:text-xs">
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/engineering-s166/computer-engineering-s2792/">
#            Computer Engineering
#           </a>
#           <span class="before:middot px-0.5 text-color-text before:no-underline">
#           </span>
#           <a class="tagged-topic !text-color-text" data-tracking-control-name="content-hub-home-page" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/engineering-s166/">
#            Engineering
#           </a>
#          </div>
#         </div>
#        </div>
#       </a>
#       <a class="content-hub-entities !no-underline" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/youre-mentoring-team-project-what-best-management-tools-iwqlf" target="_self">
#        <div class="content-hub-entity-card-redesign mt-3 mb-4 flex flex-row">
#         <img alt="You're mentoring a team on a project. What are the best project management tools to use?" aria-hidden="true" class="mr-1.5 h-full w-2 object-cover babybear:w-1" data-delayed-url="https://media.licdn.com/dms/image/D4E12AQHD3a-8t1_oEg/article-cover_image-shrink_720_1280/0/1674482574236?e=2147483647&amp;v=beta&amp;t=ot3otzYpoJQTCPxlSHCSnGRk1r-VA6qXVU5hMsIVu1o"/>
#         <div class="ml-1">
#          <a class="min-w-0 !no-underline babybear:w-full" data-tracking-control-name="full-link" data-tracking-will-navigate="" href="https://www.linkedin.com/advice/3/youre-mentoring-team-project-what-best-management-tools-iwqlf" target="_self">
#           <h2 class="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md">
#            You're mentoring a team on a project. What are the best project management tools to use?
#           </h2>
#           <div class="content-hub-contribution mb-1 mt-0.5 flex flex-row flex-wrap font-sans text-xs !font-[400] text-color-text-low-emphasis !no-underline babybear:text-[10px]">
#            <div class="face-pile flex flex-shrink-0">
#             <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#              <img alt="" class="inline-block relative rounded-[50%] w-3 h-3 face-pile__image border-1 border-solid border-color-transparent -ml-1.5 first:ml-0" data-delayed-url="https://media.licdn.com/dms/image/D4E03AQFJ8qfwdfw4Lw/profile-displayphoto-shrink_400_400/0/1676671046342?e=2147483647&amp;v=beta&amp;t=gesI5X6E3gJ30gl_cVcN0DdGRzLwVQZ7Md8UvCfXVWU" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#             </div>
#             <!-- -->
#            </div>
# ...
#          Français (French)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="हिंदी (Hindi)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="hi_IN" data-tracking-control-name="language-selector-hi_IN" lang="hi_IN" role="menuitem">
#          हिंदी (Hindi)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Bahasa Indonesia (Indonesian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="in_ID" data-tracking-control-name="language-selector-in_ID" lang="in_ID" role="menuitem">
#          Bahasa Indonesia (Indonesian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Italiano (Italian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="it_IT" data-tracking-control-name="language-selector-it_IT" lang="it_IT" role="menuitem">
#          Italiano (Italian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="日本語 (Japanese)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ja_JP" data-tracking-control-name="language-selector-ja_JP" lang="ja_JP" role="menuitem">
#          日本語 (Japanese)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="한국어 (Korean)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ko_KR" data-tracking-control-name="language-selector-ko_KR" lang="ko_KR" role="menuitem">
#          한국어 (Korean)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Bahasa Malaysia (Malay)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ms_MY" data-tracking-control-name="language-selector-ms_MY" lang="ms_MY" role="menuitem">
#          Bahasa Malaysia (Malay)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Nederlands (Dutch)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="nl_NL" data-tracking-control-name="language-selector-nl_NL" lang="nl_NL" role="menuitem">
#          Nederlands (Dutch)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Norsk (Norwegian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="no_NO" data-tracking-control-name="language-selector-no_NO" lang="no_NO" role="menuitem">
#          Norsk (Norwegian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Polski (Polish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="pl_PL" data-tracking-control-name="language-selector-pl_PL" lang="pl_PL" role="menuitem">
#          Polski (Polish)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Português (Portuguese)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="pt_BR" data-tracking-control-name="language-selector-pt_BR" lang="pt_BR" role="menuitem">
#          Português (Portuguese)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Română (Romanian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ro_RO" data-tracking-control-name="language-selector-ro_RO" lang="ro_RO" role="menuitem">
#          Română (Romanian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Русский (Russian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="ru_RU" data-tracking-control-name="language-selector-ru_RU" lang="ru_RU" role="menuitem">
#          Русский (Russian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Svenska (Swedish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="sv_SE" data-tracking-control-name="language-selector-sv_SE" lang="sv_SE" role="menuitem">
#          Svenska (Swedish)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="ภาษาไทย (Thai)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="th_TH" data-tracking-control-name="language-selector-th_TH" lang="th_TH" role="menuitem">
#          ภาษาไทย (Thai)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Tagalog (Tagalog)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="tl_PH" data-tracking-control-name="language-selector-tl_PH" lang="tl_PH" role="menuitem">
#          Tagalog (Tagalog)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Türkçe (Turkish)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="tr_TR" data-tracking-control-name="language-selector-tr_TR" lang="tr_TR" role="menuitem">
#          Türkçe (Turkish)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="Українська (Ukrainian)" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="uk_UA" data-tracking-control-name="language-selector-uk_UA" lang="uk_UA" role="menuitem">
#          Українська (Ukrainian)
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="简体中文 (Chinese (Simplified))" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="zh_CN" data-tracking-control-name="language-selector-zh_CN" lang="zh_CN" role="menuitem">
#          简体中文 (Chinese (Simplified))
#         </button>
#        </li>
#        <li class="language-selector__item" role="presentation">
#         <!-- Adding aria-label to both the li and the button because screen reader focus goes to button on desktop and li on mobile-->
#         <button aria-label="正體中文 (Chinese (Traditional))" class="font-sans text-xs link block py-[5px] px-2 w-full hover:cursor-pointer hover:bg-color-action hover:text-color-text-on-dark focus:bg-color-action focus:text-color-text-on-dark language-selector__link !font-regular" data-locale="zh_TW" data-tracking-control-name="language-selector-zh_TW" lang="zh_TW" role="menuitem">
#          正體中文 (Chinese (Traditional))
#         </button>
#        </li>
#        <!-- -->
#       </ul>
#       <button aria-expanded="false" class="language-selector__button select-none relative pr-2 font-sans text-xs font-bold text-color-text-low-emphasis hover:text-color-link-hover hover:cursor-pointer focus:text-color-link-focus focus:outline-dotted focus:outline-1" data-tracking-control-name="footer-lang-dropdown_trigger">
#        <span class="language-selector__label-text mr-0.5 break-words">
#         Language
#        </span>
#        <icon class="language-selector__label-chevron w-2 h-2 absolute top-0 right-0" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/cyolgscd0imw2ldqppkrb84vo">
#        </icon>
#       </button>
#      </div>
#     </li>
#    </ul>
#    <!-- -->
#   </footer>
#   <form action="/uas/login-submit" class="google-auth base-page__google-auth" method="post">
#    <input name="loginCsrfParam" type="hidden" value="15b6d0b3-45c9-44b1-8a88-0675c18fdb0f"/>
#    <input name="session_redirect" type="hidden" value="https://www.linkedin.com/pulse/topics/home/"/>
#    <input name="trk" type="hidden" value="d_career_advice_hub_home_google-one-tap-submit"/>
#    <code id="termsAndConditionsRendered" style="display: none">
#     <!--true-->
#    </code>
#    <div class="google-one-tap__module hidden fixed flex flex-col items-center top-[20px] right-[20px] z-[9999]">
#     <div class="relative top-2 bg-color-background-container-tint pl-2 pr-1 pt-2 pb-3 w-[375px] rounded-md shadow-2xl">
#      <p class="text-md font-bold text-color-text">
#       Agree &amp; Join LinkedIn
#      </p>
#      <p class="text-sm text-color-text" data-impression-id="d_career_advice_hub_home_one-tap-skip-tc-text">
#       By clicking Continue, you agree to LinkedIn’s
#       <a data-tracking-control-name="undefined_google-auth-button_user-agreement" data-tracking-will-navigate="true" href="/legal/user-agreement?trk=undefined_google-auth-button_user-agreement" target="_blank">
#        User Agreement
#       </a>
#       ,
#       <a data-tracking-control-name="undefined_google-auth-button_privacy-policy" data-tracking-will-navigate="true" href="/legal/privacy-policy?trk=undefined_google-auth-button_privacy-policy" target="_blank">
#        Privacy Policy
#       </a>
#       , and
#       <a data-tracking-control-name="undefined_google-auth-button_cookie-policy" data-tracking-will-navigate="true" href="/legal/cookie-policy?trk=undefined_google-auth-button_cookie-policy" target="_blank">
#        Cookie Policy
#       </a>
#       .
#      </p>
#     </div>
#     <div data-tracking-control-name="d_career_advice_hub_home_google-one-tap" id="google-one-tap__container">
#     </div>
#    </div>
#    <div class="loader loader--full-screen">
#     <div class="loader__container mb-2 overflow-hidden">
#      <icon class="loader__icon inline-block loader__icon--default text-color-progress-loading" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--large fill-currentColor h-[60px] min-h-[60px] w-[60px] min-w-[60px]">
#      </icon>
#     </div>
#    </div>
#   </form>
#   <script data-delayed-url="https://static.licdn.com/aero-v1/sc/h/8m736dfzskmdn6bwwqz67iiki" data-module-id="google-gsi-lib">
#   </script>
#   <code id="googleAuthLibraryPath" style="display: none">
#    <!--"https://static.licdn.com/aero-v1/sc/h/8m736dfzskmdn6bwwqz67iiki"-->
#   </code>
#   <code id="isLinkedInAppWebView" style="display: none">
#    <!--false-->
#   </code>
#   <code id="isTermsAndConditionsSkipEnabledOneTap" style="display: none">
#    <!--true-->
#   </code>
#   <script async="" src="https://static.licdn.com/aero-v1/sc/h/3d2uuwcrkw7zs4mcvzknqukxi">
#   </script>
#   <!-- -->
#   <script async="" defer="" src="https://static.licdn.com/aero-v1/sc/h/36xrev08adp8br0tcapfqcdy8">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ###### getting title of this page

# %%
title=soup.find('title') 
print(title.text)
# Out:
# Discover thousands of collaborative articles on 2500+ skills

# %% [markdown]
# ###### Extracting the content from a specific section of the page

# %%
content=soup.find("div",class_="core-section-container__content break-words")
print(content.text)
# Out:
# We’re unlocking community knowledge in an all new way. It starts with an article on a professional topic or skill, written with the help of AI — but it’s not complete without insights and advice from people with real-life experiences. We invited experts to contribute. Learn more

# %% [markdown]
# ###### Using find all we can extract all data related to tag and class

# %%
# Extracting questions
Question=soup.find_all("h2",class_="mb-1 overflow-hidden break-words font-sans text-lg font-[500] babybear:text-md")
Questions=[]
for i in Question:
    Questions.append(i.text)
print(Questions)
# Out:
# ['Your team is struggling to keep up with productivity. What mentoring software should you consider?', "What are the most effective tools for managing your technical support team's schedules?", "You're managing a virtual team. How can you ensure project management success?", 'Your HR department needs mentoring tools. How do you choose the best ones?', 'What does an electronic specialist do?', "You're mentoring a team on a project. What are the best project management tools to use?", 'What does a food service order clerk do?', 'You’re struggling to improve your public speaking skills. How can you overcome this challenge?', 'How can you create effective teacher workshops?', "You're a creative strategist with limited time. Which content creation tools can you master quickly?", 'How do you become a banquet bartender?', 'What is the most effective way to test ETL workflows for accuracy and completeness?', 'You need to analyze your business content. What are the best tools for the job?', "You're a professional looking to upskill. What are the top-rated interview preparation courses for you?", 'What does a sound designer do?', 'How can you use energy-efficient design strategies to improve acoustics in buildings?', 'How do you leverage LEED as a tool for social and environmental justice and equity?', 'You have a content marketing project to launch. How can you find the best services to help you succeed?', 'How do you become a sales project manager?', 'You’re working on a Systems Design project. How can you make your flowcharts stand out?', 'How can you use drones to make your conference more interactive?', "You're looking to build your professional network. How can you find the right tools to manage it?", 'How can you optimize 3D animations for AR experiences with multiple users?', 'You’re in charge of safety equipment for environmental services. What are the most innovative solutions?', 'You’re struggling to choose the best email marketing tools for your digital campaigns. What are your options?', 'Your procurement team is struggling with contract management. How can you help them?', 'What are the most unique ways to use framing in light painting photography?', "You're working on a Client Relations project. What Salesforce automation software should you use?", "You're conducting a performance appraisal. What tools should you use to get the best results?", 'You’re a teacher who wants to create engaging quizzes and tests. How can you align them with your curriculum?', 'What are the best practices for facilitating co-creation and collaboration among diverse stakeholders?', 'You need to engage donors. What are the best CRM tools to help you do it?', 'How can you create a marketing campaign that sells out an event?', 'You’re starting a new manufacturing project. How do you choose the most reliable industrial robots?', 'What is the difference between control and specification limits?', "You want to track your team's productivity. What email tracking software should you use?", "Your remote team is growing and you need to stay organized. What's the best way to do it?", 'How can LEED v4.1 encourage innovation and collaboration among health and sustainability professionals?', 'How do you become a temporary human resources assistant?', 'How can you use programming languages to secure AR applications from malware and viruses?', "You're looking to advance your career. What are the best import/export training courses for you?", 'How can you create a dynamic atmosphere in your podcast?', 'You’re looking to create architectural models with 3D printing. What tools should you use?', 'How can you manage staff turnover in banquet operations?', 'You’re struggling to engage stakeholders. How can you use stakeholder analysis tools to turn things around?', "Your team's productivity is suffering. How can you use sales performance tools to improve it?", 'How can you keep offshore innovation and R&D within budget?', 'How can you effectively handle conflicts du ...

# %%
# Extracting contribution counts
contribution=soup.find_all("span",class_="pr-0.5 pt-0.5")
contributions=[]
for i in contribution:
    contributions.append(i.text.strip())
print(contributions)
# Out:
# ['45 contributions', '18 contributions', '38 contributions', '21 contributions', '5 contributions', '21 contributions', '1 contribution', '52 contributions', '12 contributions', '20 contributions', '2 contributions', '4 contributions', '8 contributions', '25 contributions', '5 contributions', '1 contribution', '1 contribution', '43 contributions', '12 contributions', '4 contributions', '3 contributions', '4 contributions', '2 contributions', '2 contributions', '35 contributions', '3 contributions', '6 contributions', '11 contributions', '17 contributions', '7 contributions', '10 contributions', '1 contribution', '6 contributions', '6 contributions', '2 contributions', '6 contributions', '6 contributions', '1 contribution', '10 contributions', '1 contribution', '6 contributions', '4 contributions', '4 contributions', '3 contributions', '3 contributions', '17 contributions', '1 contribution', '13 contributions', '17 contributions', '7 contributions', '4 contributions', '10 contributions', '2 contributions', '8 contributions', '1 contribution', '5 contributions', '1 contribution', '3 contributions', '11 contributions', '2 contributions', '4 contributions', '10 contributions', '8 contributions', '8 contributions', '2 contributions', '8 contributions', '1 contribution', '14 contributions', '2 contributions', '14 contributions', '11 contributions', '4 contributions', '4 contributions', '3 contributions', '8 contributions', '9 contributions', '24 contributions', '29 contributions', '6 contributions', '10 contributions', '3 contributions', '11 contributions', '7 contributions', '9 contributions', '2 contributions', '3 contributions', '10 contributions', '2 contributions', '5 contributions', '10 contributions', '5 contributions', '7 contributions', '10 contributions', '1 contribution', '19 contributions', '6 contributions', '21 contributions', '13 contributions', '5 contributions', '3 contributions']

# %%
# Extracting timestamps
timestamps=soup.find_all("span",class_="before:middot pt-0.5")
timestamp=[]
for i in timestamps:
    timestamp.append(i.text.strip())
print(timestamp)
# Out:
# ['6 minutes ago', '3 minutes ago', '1 minute ago', '23 minutes ago', '9 hours ago', '51 minutes ago', '10 hours ago', '3 minutes ago', '1 hour ago', '7 minutes ago', '10 hours ago', '28 minutes ago', '23 minutes ago', '10 minutes ago', '1 hour ago', '10 hours ago', '10 hours ago', '1 minute ago', '1 hour ago', '4 hours ago', '4 hours ago', '14 minutes ago', '5 hours ago', '37 minutes ago', '8 minutes ago', '5 hours ago', '34 minutes ago', '1 hour ago', '30 minutes ago', '2 hours ago', '2 hours ago', '10 hours ago', '5 hours ago', '2 hours ago', '3 hours ago', '2 hours ago', '2 hours ago', '10 hours ago', '15 minutes ago', '10 hours ago', '43 minutes ago', '2 hours ago', '3 hours ago', '10 hours ago', '3 hours ago', '1 hour ago', '10 hours ago', '2 hours ago', '2 minutes ago', '4 hours ago', '4 hours ago', '8 minutes ago', '10 hours ago', '3 hours ago', '10 hours ago', '2 hours ago', '11 hours ago', '11 hours ago', '15 minutes ago', '4 hours ago', '3 hours ago', '52 minutes ago', '51 minutes ago', '1 hour ago', '17 minutes ago', '19 minutes ago', '11 hours ago', '2 hours ago', '11 hours ago', '1 hour ago', '1 hour ago', '1 hour ago', '11 hours ago', '11 hours ago', '25 minutes ago', '1 hour ago', '46 minutes ago', '29 minutes ago', '11 hours ago', '3 minutes ago', '1 hour ago', '39 minutes ago', '3 hours ago', '1 hour ago', '1 hour ago', '11 hours ago', '3 hours ago', '3 hours ago', '11 hours ago', '43 minutes ago', '35 minutes ago', '2 hours ago', '4 hours ago', '11 hours ago', '31 minutes ago', '10 hours ago', '1 hour ago', '2 minutes ago', '17 minutes ago', '11 hours ago']

# %%
# Extracting descriptions of article
desc=soup.find_all("p",class_="content-description mt-0.5 break-words font-sans text-sm font-normal babybear:text-xs")
description=[]
for i in desc:
    description.append(i.text.strip())
print(description)
# Out:
# ["Learn how to choose the best mentoring software for your team's productivity. Consider features, ease of use, support, cost, reviews, and trial.", "Learn about the best tools to automate, optimize, and streamline your technical support team's schedules, and improve your team's productivity, satisfaction, and…", 'Learn how to use facilitation skills and tools to manage your virtual team and project effectively and successfully.', 'Learn how to find the best mentoring tools for your HR department. Discover how to assess your needs, compare your options, and test your choices.', 'Learn what an electronic specialist does, what skills and qualifications you need, and what industries and sectors you can work in.', 'Learn how to use the best project management tools to mentor your team on a project. Discover how to define your goals, choose a platform, use a framework, and more.', 'Learn what a food service order clerk does, what skills and qualifications are required, and what are the benefits and challenges of this career.', 'Learn how to improve your public speaking skills with these six practical steps. Find out how to identify your fears, prepare and practice, seek feedback and…', 'Learn how to plan and facilitate successful teacher workshops for professional development and networking. Follow these tips to tailor your workshop to your…', 'Learn how to create engaging and effective content for your projects with these easy and affordable tools for visuals, videos, audio, and text.', 'Learn what skills and qualifications you need to become a banquet bartender, how to find and apply for jobs, and what to expect from the work.', 'Learn the most effective ways to test ETL workflows for data quality and reliability, and what tools and techniques to use for automation and simplification.', 'Learn how to perform content analysis with the best tools available. Find out how to audit, analyze, improve, and test your business content.', 'Learn how to ace your next job interview with these top-rated interview preparation courses. Find the best course for your goals, industry, and budget.', 'Learn what a sound designer does, what skills and tools they need, and how they collaborate with other professionals in this informative article.', 'Learn how to use energy-efficient design strategies to reduce noise transmission, enhance sound absorption, and optimize sound distribution in buildings.', 'Learn how to leverage LEED to create positive impacts for people and the planet. Explore benefits, steps, and examples of LEED projects.', 'Learn how to choose, evaluate, work with, and learn from content marketing services for your content marketing project. Discover how to achieve your goals…', 'Learn what a sales project manager does, what skills you need, how to gain experience, how to get certified, and how to advance your career.', 'Learn how to create flowcharts that are attractive, readable, and consistent for systems design. Follow these six steps to choose the right tool, follow the…', 'Learn how to use drones to create engaging and memorable shows for your conference attendees. Discover the benefits, challenges, tips, and best practices of using…', 'Learn how to manage your professional network with the right tools. Discover how to define your goals, research your options, test and trial, choose and commit, and…', 'Learn how to optimize 3D animations for AR experiences with multiple users by choosing the right format, reducing polygon count, using occlusion culling, and…', 'Discover the most innovative solutions for environmental services safety equipment, such as smart sensors, wearable technology, biodegradable materials, and more.', 'Learn what to look for in email marketing tools and discover some of the popular options for your digital campaigns.', "Learn how to improve your procurement team's contract management skills and efficiency with these tips and tools, such as contract management software.", 'Learn some of the most unique ways  ...

# %%
# Extracting tagged topics article
topic=soup.find_all("a",class_="tagged-topic !text-color-text")
topics=[]
j=1
for i in topic:
    topics.append(i.text.strip())
    j=j+1
    if j>100:
        break;
print(topics)
len(topics)
# Out:
# ['Mentoring', 'Soft Skills', 'Technical Support', 'IT Services', 'Facilitation', 'Soft Skills', 'Mentoring', 'Soft Skills', 'Computer Engineering', 'Engineering', 'Mentoring', 'Soft Skills', 'F&B Operations', 'Food and Beverage Management', 'Business Communications', 'Business Administration', 'Teaching', 'Education', 'Creative Strategy', 'Marketing', 'F&B Operations', 'Food and Beverage Management', 'Database Administration', 'Engineering', 'Content Development', 'Content Management', 'Career Development Coaching', 'HR Management', 'Design', 'Art', 'Environmental Design', 'Sustainability', 'Leadership in Energy and Environmental Design (LEED)', 'Content Marketing', 'Marketing', 'Project Leadership', 'Soft Skills', 'Systems Design', 'Engineering', 'Event Planning', 'Marketing', 'Business Operations', 'Business Administration', 'Augmented Reality (AR)', 'Engineering', 'Environmental Services', 'Public Administration', 'Digital Strategy', 'Marketing', 'Vendor Negotiation', 'Soft Skills', 'Photography', 'Art', 'Client Relations', 'Sales', 'People Management', 'Soft Skills', 'Educational Technology', 'Education', 'Capacity Building', 'Philanthropy', 'Public Administration', 'Event Production', 'Content Management', 'Manufacturing Engineering', 'Engineering', 'Industrial Control', 'Interpersonal Communication', 'Soft Skills', 'Time Management', 'Soft Skills', 'Leadership in Energy and Environmental Design (LEED)', 'Staffing Services', 'HR Management', 'Augmented Reality (AR)', 'Engineering', 'Import/Export Operations', 'Sales', 'Content Development', 'Content Management', 'Architectural Design', 'Culinary Management', 'Food and Beverage Management', 'Senior Stakeholder Management', 'Business Administration', 'Sales Coaching', 'Sales', 'Petroleum Engineering', 'Oil and Gas', 'Conferences', 'Business Administration', 'Content Marketing', 'Marketing', 'Software Testing', 'Engineering', 'Transportation Planning', 'Engineering', 'Business Development', 'Business Administration', 'Presentations']
# 100

# %% [markdown]
# ###### Creating a DataFrame

# %%
df=pd.DataFrame()

# %%
#Adding data in dataframe
df["Questions"]=Questions
df["Description"]=description
df["Contributions"]=contributions
df["Timestamp"]=timestamp
df["Topics"]=topics
df
# Out:
#                                             Questions  \
# 0   Your team is struggling to keep up with produc...
# 1   What are the most effective tools for managing...
# 2   You're managing a virtual team. How can you en...
# 3   Your HR department needs mentoring tools. How ...
# 4              What does an electronic specialist do?
# ..                                                ...
# 95  You’re starting a new project. What product de...
# 96  You're struggling to manage employee relations...
# 97  You need to share your design system with your...
# 98  Your sales team is struggling to find new lead...
# 99  Your business is under threat from cyber attac...
#
#                                           Description     Contributions  \
# 0   Learn how to choose the best mentoring softwar...  45 contributions
# 1   Learn about the best tools to automate, optimi...  18 contributions
# 2   Learn how to use facilitation skills and tools...  38 contributions
# 3   Learn how to find the best mentoring tools for...  21 contributions
# 4   Learn what an electronic specialist does, what...   5 contributions
# ..                                                ...               ...
# 95  Learn about the most popular and useful produc...   6 contributions
# 96  Learn how HR workflow management tools can hel...  21 contributions
# 97  Learn how to communicate your design vision, c...  13 contributions
# 98  Discover the best prospecting tools that can h...   5 contributions
# 99  Learn some mobile device security solutions th...   3 contributions
#
#          Timestamp                   Topics
# 0    6 minutes ago                Mentoring
# 1    3 minutes ago              Soft Skills
# 2     1 minute ago        Technical Support
# 3   23 minutes ago              IT Services
# 4      9 hours ago             Facilitation
# ..             ...                      ...
# 95    10 hours ago  Transportation Planning
# 96      1 hour ago              Engineering
# 97   2 minutes ago     Business Development
# 98  17 minutes ago  Business Administration
# 99    11 hours ago            Presentations
#
# [100 rows x 5 columns]

# %% [markdown]
# ###### Saving the DataFrame as a CSV file

# %%
df.to_csv("linkedin_data.csv",index=False)

# %% [markdown]
# ###### Reading the saved CSV file

# %%
df_read=pd.read_csv("linkedin_data.csv")
df_read
# Out:
#                                             Questions  \
# 0   Your team is struggling to keep up with produc...
# 1   What are the most effective tools for managing...
# 2   You're managing a virtual team. How can you en...
# 3   Your HR department needs mentoring tools. How ...
# 4              What does an electronic specialist do?
# ..                                                ...
# 95  You’re starting a new project. What product de...
# 96  You're struggling to manage employee relations...
# 97  You need to share your design system with your...
# 98  Your sales team is struggling to find new lead...
# 99  Your business is under threat from cyber attac...
#
#                                           Description     Contributions  \
# 0   Learn how to choose the best mentoring softwar...  45 contributions
# 1   Learn about the best tools to automate, optimi...  18 contributions
# 2   Learn how to use facilitation skills and tools...  38 contributions
# 3   Learn how to find the best mentoring tools for...  21 contributions
# 4   Learn what an electronic specialist does, what...   5 contributions
# ..                                                ...               ...
# 95  Learn about the most popular and useful produc...   6 contributions
# 96  Learn how HR workflow management tools can hel...  21 contributions
# 97  Learn how to communicate your design vision, c...  13 contributions
# 98  Discover the best prospecting tools that can h...   5 contributions
# 99  Learn some mobile device security solutions th...   3 contributions
#
#          Timestamp                   Topics
# 0    6 minutes ago                Mentoring
# 1    3 minutes ago              Soft Skills
# 2     1 minute ago        Technical Support
# 3   23 minutes ago              IT Services
# 4      9 hours ago             Facilitation
# ..             ...                      ...
# 95    10 hours ago  Transportation Planning
# 96      1 hour ago              Engineering
# 97   2 minutes ago     Business Development
# 98  17 minutes ago  Business Administration
# 99    11 hours ago            Presentations
#
# [100 rows x 5 columns]
